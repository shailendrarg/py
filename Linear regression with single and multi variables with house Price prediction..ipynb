# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model # for machine learning REGRESSION

df= pd.read_csv("House_file.csv",nrows=30)
df
# Out:
#     Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0      1  114300  1790         2          2       2    No         East
# 1      2  114200  2030         4          2       3    No         East
# 2      3  114800  1740         3          2       1    No         East
# 3      4   94700  1980         3          2       3    No         East
# 4      5  119800  2130         3          3       3    No         East
# 5      6  114600  1780         3          2       2    No        North
# 6      7  151600  1830         3          3       3   Yes         West
# 7      8  150700  2160         4          2       2    No         West
# 8      9  119200  2110         4          2       3    No         East
# 9     10  104000  1730         3          3       3    No         East
# 10    11  132500  2030         3          2       3   Yes         East
# 11    12  123000  1870         2          2       2   Yes         East
# ...

# %%
#dropping last columns
df.dropna(inplace=True,axis=1)

# %%
df.isnull().sum() #check for missing data
# Out:
# Home            0
# Price           0
# SqFt            0
# Bedrooms        0
# Bathrooms       0
# Offers          0
# Brick           0
# Neighborhood    0
# dtype: int64

# %%
#check for duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#     Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0      1  114300  1790         2          2       2    No         East
# 1      2  114200  2030         4          2       3    No         East
# 2      3  114800  1740         3          2       1    No         East
# 3      4   94700  1980         3          2       3    No         East
# 4      5  119800  2130         3          3       3    No         East
# 5      6  114600  1780         3          2       2    No        North
# 6      7  151600  1830         3          3       3   Yes         West
# 7      8  150700  2160         4          2       2    No         West
# 8      9  119200  2110         4          2       3    No         East
# 9     10  104000  1730         3          3       3    No         East
# 10    11  132500  2030         3          2       3   Yes         East
# 11    12  123000  1870         2          2       2   Yes         East
# ...

# %%
#setting Home as index
df.set_index("Home",inplace = True)

# %%
df.head(30)
# Out:
#        Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# Home
# 1     114300  1790         2          2       2    No         East
# 2     114200  2030         4          2       3    No         East
# 3     114800  1740         3          2       1    No         East
# 4      94700  1980         3          2       3    No         East
# 5     119800  2130         3          3       3    No         East
# 6     114600  1780         3          2       2    No        North
# 7     151600  1830         3          3       3   Yes         West
# 8     150700  2160         4          2       2    No         West
# 9     119200  2110         4          2       3    No         East
# 10    104000  1730         3          3       3    No         East
# 11    132500  2030         3          2       3   Yes         East
# 12    123000  1870         2          2       2   Yes         East
# 13    102600  1910         3          2       4    No        North
# ...

# %%
df.shape
# Out:
# (30, 7)

# %%
#Plotting the data as per the matplotlib
plt.scatter(df.SqFt,df.Price,visible=True)

# %%
#linearr regression
reg=linear_model.LinearRegression()
reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.fit(df[["SqFt"]],df.Price)# fit(2d array,y intercept)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([77.5163628])

# %%
reg.intercept_
# Out:
# -26582.768065620607

# %%
reg.predict([[2100]]) 
#is not working so using linear equaion
#area= 2100
#y= m*x+b--> reg.coef_*area+reg.intercept_
#price= 77.5163628 *area-26582.768065620607
#print("Price for the area is", price )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-658a33a28e47> in <module>
# ----> 1 reg.predict([[2100]])
#       2 #is not working so using linear equaion
#       3 #area= 2100
#       4 #y= m*x+b--> reg.coef_*area+reg.intercept_
#       5 #price= 77.5163628 *area-26582.768065620607
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
# --> 198                                dense_output=True) + self.intercept_
# ...

# %% [markdown]
# # Linear regression using multi vaiable
# # y= m1*x1 +m2*x2 +c

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["SqFt","Bedrooms"]],df.Price)# fit(2d array,y intercept)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
df[["SqFt","Bedrooms"]].size
# Out:
# 60

# %%
df["Price"].size
# Out:
# 30

# %%
plt.scatter(df[["SqFt"]],df.Price)

# %%
reg.coef_  # m1 and m2
# Out:
# array([   53.21067794, 13438.36116218])

# %%
reg.intercept_ # intercept c
# Out:
# -21700.983454314628

# %%
predicted_price=reg.predict([[2100,2]])
#y= m1*x1+m2*x2+c
calc_price = 53.21067794*2100+13438.36116218*2-21700.98345431462
predicted_price,calc_price
#there is a variation here for the
# Out:
# (array([116918.16253814]), 116918.16254404536)
